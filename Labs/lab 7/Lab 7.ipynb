# %% [markdown]
# Your name goes here Pleaese

# %% [markdown]
# ## Lab Objective:
# Create a Python script that recursively searches a file system for files with identical names. Perform a comparison on files and output the file paths of identical files.
#
# ## Required tasks
# 1. A menu
#     - this should be fairly easy seeing as your games (should) already have a menu system
# 2. Recursive Search
#     - a recursive search is a search that will travle into a folder and back out.
# 3. Comparison
#     - I recomend using a check sum comparison operation like MD5 or SHA-256
# 4. Output
#     - the program will output files and there directories
#         - this can be done live or after
#
# ## Instructions:
# Submit the file as a .py show it running in a .ipynb file
#
#
# Please find some sample code below to get you started

# %%
import os
import hashlib

def menu():
    while True:
        print("\n--- File Duplicate Finder ---")
        print("1. Enter directory to search")
        print("2. Exit")
        choice = input("Choose an option: ")

def find_duplicates(directory):
    # search os.walk(directory):
    # use a dictionary to store file names and paths
    # compare files with the same name


def get_checksum(file_path):
    hash_obj = hashlib.md5()  # Change to hashlib.sha256() if desired
    with open(file_path, 'rb') as f:
        while chunk := f.read(8192):
            hash_obj.update(chunk)
    return hash_obj.hexdigest()


if __name__ == "__main__":
    menu()

# %%
import os
import hashlib

def menu():
    while True:
        print("\n--- File Duplicate Finder ---")
        print("1. Enter directory to search")
        print("2. Exit")
        choice = input("Choose an option: ")

        if choice == '1':
            directory = input("Enter the directory path: ")
            find_duplicates(directory)
        elif choice == '2':
            print("Exiting program.")
            break
        else:
            print("Invalid choice. Please try again.")

def find_duplicates(directory):
    if not os.path.isdir(directory):
        print(f"The directory {directory} does not exist.")
        return
    
    # Dictionary to store file checksums (hashes)
    checksums = {}
    
    # Walk through the directory and its subdirectories
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            file_hash = get_checksum(file_path)
            
            if file_hash in checksums:
                checksums[file_hash].append(file_path)
            else:
                checksums[file_hash] = [file_path]
    
    # Check for duplicates and print them
    duplicates_found = False
    for file_hash, file_paths in checksums.items():
        if len(file_paths) > 1:
            duplicates_found = True
            print(f"\nDuplicate files with hash {file_hash}:")
            for path in file_paths:
                print(path)

    if not duplicates_found:
        print("No duplicate files found.")

def get_checksum(file_path):
    hash_obj = hashlib.md5()  # You can change to hashlib.sha256() if you want
    with open(file_path, 'rb') as f:
        while chunk := f.read(8192):
            hash_obj.update(chunk)
    return hash_obj.hexdigest()

if __name__ == "__main__":
    menu()
# Out:
# --- File Duplicate Finder ---
# 1. Enter directory to search
# 2. Exit
# The directory C:\Users\Andrew\Documents does not exist.
#
# --- File Duplicate Finder ---
# 1. Enter directory to search
# 2. Exit
# The directory C:\Users\Andrew\Documents does not exist.
#
# --- File Duplicate Finder ---
# 1. Enter directory to search
# 2. Exit
#
# Duplicate files with hash d41d8cd98f00b204e9800998ecf8427e:
# C:\Users\Owner\Downloads\homeworkfolder-andrewm3412\Homework\Homework1\Homework1.ipynb
# C:\Users\Owner\Downloads\homeworkfolder-andrewm3412\Labs\Lab1\lab1.ipynb
#
# --- File Duplicate Finder ---
# 1. Enter directory to search
# 2. Exit
# Exiting program.
